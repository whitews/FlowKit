# %%
import bokeh
from bokeh.plotting import show

import flowkit as fk

bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
fcs_path = '../examples/gate_ref/data1.fcs'
sample = fk.Sample(fcs_path)

# %%
p = sample.plot_scatter(source='raw', x_label_or_number='FL1-H', y_label_or_number='FL2-H')
show(p)
# Out:
#   <div class="bk-root" id="24b0589c-2efb-46d7-93df-5f7e64110e1e" data-root-id="1002"></div>

# %%
xform = fk.transforms.LinearTransform('lin', param_t=10000, param_a=0)
sample.apply_transform(xform)

p = sample.plot_scatter(source='xform', x_label_or_number='FL1-H', y_label_or_number='FL2-H')
show(p)
# Out:
#   <div class="bk-root" id="213ba53b-10aa-4822-8e72-939859a72928" data-root-id="1104"></div>

# %%
xform = fk.transforms.LogicleTransform('logicle', param_t=10000, param_w=0.5, param_m=4.5, param_a=0)
sample.apply_transform(xform)

p = sample.plot_scatter(source='xform', x_label_or_number='FL1-H', y_label_or_number='FL2-H')
show(p)
# Out:
#   <div class="bk-root" id="34e6ee45-91e8-4a5e-ae49-b89ad51fa198" data-root-id="1214"></div>

# %%
xform = fk.transforms.AsinhTransform('asinh', param_t=10000, param_m=4.5, param_a=0)
sample.apply_transform(xform)

p = sample.plot_scatter(source='xform', x_label_or_number='FL1-H', y_label_or_number='FL2-H')
show(p)
# Out:
#   <div class="bk-root" id="abf3d940-70db-47a3-a4d1-b2e94865e76f" data-root-id="1332"></div>

# %%
xform = fk.transforms.HyperlogTransform('hyper', param_t=10000, param_w=0.5, param_m=4.5, param_a=0)
sample.apply_transform(xform)

p = sample.plot_scatter(source='xform', x_label_or_number='FL1-H', y_label_or_number='FL2-H')
show(p)
# Out:
#   <div class="bk-root" id="305adda8-bd2c-4f55-abdf-23897c1c5c55" data-root-id="1458"></div>

# %%
xform = fk.transforms.LogTransform('log', param_t=10000, param_m=4.5)
sample.apply_transform(xform)

p = sample.plot_scatter(source='xform', x_label_or_number='FL1-H', y_label_or_number='FL2-H')
show(p)
# Out:
# /home/swhite/envs/py3-flowkit-dev/lib/python3.8/site-packages/flowutils/transforms.py:250: RuntimeWarning: divide by zero encountered in log10
#   data_copy[:, channel_indices] = (1. / m) * np.log10(data_copy[:, channel_indices] / t) + 1.
#   <div class="bk-root" id="ec9678fc-d35e-43a3-b4cd-3f884fb6411f" data-root-id="1592"></div>

# %%
xform = fk.transforms.WSPLogTransform('log', offset=1, decades=4.5)
sample.apply_transform(xform)

p = sample.plot_scatter(source='xform', x_label_or_number='FL1-H', y_label_or_number='FL2-H')
show(p)
# Out:
#   <div class="bk-root" id="c51becaf-ef7f-4a6e-ac4e-21eb682cdb01" data-root-id="1734"></div>

# %%
xform = fk.transforms.WSPBiexTransform(
    'biex',
    negative=0,
    width=-10,
    positive=4.5,
    max_value=10000,
)
sample.apply_transform(xform)

p = sample.plot_scatter(source='xform', x_label_or_number='FL1-H', y_label_or_number='FL2-H')
show(p)
# Out:
#   <div class="bk-root" id="4e4d5763-20c7-4e20-8358-668592a783a3" data-root-id="1884"></div>
