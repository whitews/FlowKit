# %%
import bokeh
from bokeh.plotting import show

import flowkit as fk

bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
fcs_path = '../examples/gate_ref/data1.fcs'
sample = fk.Sample(fcs_path)

# %%
p = sample.plot_scatter(source='raw', x_label_or_number='FL1-H', y_label_or_number='FL2-H')
show(p)
# Out:
#   <div class="bk-root" id="d088491a-ab2a-4a11-b048-78dca65e5bd1" data-root-id="1002"></div>

# %%
xform = fk.transforms.LinearTransform('lin', param_t=10000, param_a=0)
sample.apply_transform(xform)

p = sample.plot_scatter(source='xform', x_label_or_number='FL1-H', y_label_or_number='FL2-H')
show(p)
# Out:
#   <div class="bk-root" id="ba67ef2f-d3e8-4668-92a7-9c4f4abdc1d4" data-root-id="1104"></div>

# %%
xform = fk.transforms.LogicleTransform('logicle', param_t=10000, param_w=0.5, param_m=4.5, param_a=0)
sample.apply_transform(xform)

p = sample.plot_scatter(source='xform', x_label_or_number='FL1-H', y_label_or_number='FL2-H')
show(p)
# Out:
#   <div class="bk-root" id="0fb1d4ea-4ace-479b-a489-95d0602bbdab" data-root-id="1214"></div>

# %%
xform = fk.transforms.AsinhTransform('asinh', param_t=10000, param_m=4.5, param_a=0)
sample.apply_transform(xform)

p = sample.plot_scatter(source='xform', x_label_or_number='FL1-H', y_label_or_number='FL2-H')
show(p)
# Out:
#   <div class="bk-root" id="e3287672-8ba1-4383-8d91-44e3dc359a46" data-root-id="1332"></div>

# %%
xform = fk.transforms.HyperlogTransform('hyper', param_t=10000, param_w=0.5, param_m=4.5, param_a=0)
sample.apply_transform(xform)

p = sample.plot_scatter(source='xform', x_label_or_number='FL1-H', y_label_or_number='FL2-H')
show(p)
# Out:
#   <div class="bk-root" id="000ffa63-0914-410a-8a14-333e3b1e68cb" data-root-id="1458"></div>

# %%
xform = fk.transforms.LogTransform('log', param_t=10000, param_m=4.5)
sample.apply_transform(xform)

p = sample.plot_scatter(source='xform', x_label_or_number='FL1-H', y_label_or_number='FL2-H')
show(p)
# Out:
# /home/swhite/envs/py3-flowkit-dev/lib/python3.8/site-packages/FlowKit-0.4.1b0-py3.8-linux-x86_64.egg/flowkit/_models/transforms/transforms.py:99: RuntimeWarning: divide by zero encountered in log10
#   new_events = (1. / self.param_m) * np.log10(events / self.param_t) + 1.
#   <div class="bk-root" id="295cc5c2-5dd6-4c72-b873-6626658a391b" data-root-id="1592"></div>

# %%
xform = fk.wsp_transforms.WSPLogTransform('log', offset=1, decades=4.5)
sample.apply_transform(xform)

p = sample.plot_scatter(source='xform', x_label_or_number='FL1-H', y_label_or_number='FL2-H')
show(p)
# Out:
#   <div class="bk-root" id="3de4abcb-cca5-4ca9-82eb-dfdc394c5df5" data-root-id="1734"></div>
